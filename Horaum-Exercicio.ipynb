# %% [markdown]
# # Análise de filmes Brasileiros e Estrangeiros exibidos de 2009 a 2019

# %% [markdown]
# ### Importando o PANDAS

# %%
import pandas as pd

# %% [markdown]
# # Criando a variável url apontando para o DataSet dos filmes
# * Inserindo os dados em um variável dados
# * Abrindo a varável dados para vizualização dos dados do DataSet
#
# ### Observe que o arquivo csv está separado por virgulas, que é o padrão da função read_csv(), não sendo necessáro o comando pd.read_csv(url,sep=";") para separar por ";"

# %%
url="DataSet/Listagem_dos_Filmes_Brasileiros_e_Estrangeiros_Exibidos_2009_a_2019.csv"

dados= pd.read_csv(url)

dados
# Out:
#       Unnamed: 0  Ano de exibição              Título da obra        Gênero  \
# 0              0             2019   120 Batimentos Por Minuto        Ficção
# 1              1             2019                     3 Faces        Ficção
# 2              2             2019            45 Dias Sem Você        Ficção
# 3              3             2019    A 100 Passos De Um Sonho        Ficção
# 4              4             2019  A Abelhinha Maya - O Filme      Animação
# ...          ...              ...                         ...           ...
# 7047        7076             2009                 Xuxa Gêmeas        Ficção
# 7048        7077             2009                Zico na Rede  Documentário
# 7049        7078             2009                    À Deriva        Ficção
# 7050        7079             2009            É Proibido Fumar        Ficção
# 7051        7080             2009         Última Parada - 174        Ficção
#
# ...

# %% [markdown]
# # Análisando o tipo de dados da variável dados

# %%
print (f'Tipo de dados da variável dados: {type(dados)}')
# Out:
# Tipo de dados da variável dados: <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # Analisando as 30 primeiras linhas da tabela
# * Utilizando o comando dados.head() para filtrar a quantidade de linhas exibidas pelo DataFrame

# %%
dados.head(30)
# Out:
#     Unnamed: 0  Ano de exibição                   Título da obra  \
# 0            0             2019        120 Batimentos Por Minuto
# 1            1             2019                          3 Faces
# 2            2             2019                 45 Dias Sem Você
# 3            3             2019         A 100 Passos De Um Sonho
# 4            4             2019       A Abelhinha Maya - O Filme
# 5            5             2019          A Batalha Das Correntes
# 6            6             2019                  A Bela da Tarde
# 7            7             2019   A Cabeça De Gumercindo Saraiva
# 8            8             2019                A Caminho De Casa
# 9            9             2019               A Casa De Veraneio
# 10          10             2019        A Casa Que Jack Construiu
# 11          11             2019             A Cidade Dos Piratas
# 12          12             2019           A Cinco Passos De Você
# ...

# %% [markdown]
# # Analisando as ultimas 30 linhas da tabela

# %%
dados.tail(30)
# Out:
#       Unnamed: 0  Ano de exibição                       Título da obra  \
# 7022        7050             2009                 Up - Altas Aventuras
# 7023        7051             2009                     Valsa com Bashir
# 7024        7052             2009               Valsa para Bruno Stein
# 7025        7054             2009                       Velhas Guardas
# 7026        7055             2009                 Velozes e Furiosos 4
# 7027        7056             2009                  Vermelho Como o Céu
# 7028        7057             2009                             Verônica
# 7029        7058             2009               Verônika Decide Morrer
# 7030        7059             2009  Viagem ao Centro da Terra - O Filme
# 7031        7060             2009             Vicky Cristina Barcelona
# 7032        7061             2009                           Vigaristas
# 7033        7062             2009                              Vila 21
# ...
